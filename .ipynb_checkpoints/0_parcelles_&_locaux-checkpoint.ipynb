# %%
import pandas as pd
import glob

# %%
pd.set_option('display.max_columns', None)

# %%
df_parc1 = pd.concat([pd.read_csv(i, sep=';', encoding='latin', low_memory=False) for i in glob.glob(
    "../0_data/parcelles/Fichier des parcelles (situation 2022)-dept 01 à 61/Fichier des parcelles (situation 2022)-dpts 01 à 61/*.txt",
    recursive=True)])
df_parc2 = pd.concat([pd.read_csv(i, sep=';', encoding='latin', low_memory=False) for i in glob.glob(
    "../0_data/parcelles/Fichier des parcelles (situation 2022)-dept 62 à 976/Fichier des parcelles (situation 2022)-dpts 62 à 976/*.txt",
    recursive=True)])
df_parc = pd.concat([df_parc1, df_parc2], axis=0)

# %%
df_parc
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 0                                    1                                    0  \
# 1                                    1                                    0
# 2                                    1                                    0
# 3                                    1                                    0
# 4                                    1                                    0
# ...                                ...                                  ...
# 38937                               97                                    6
# 38938                               97                                    6
# 38939                               97                                    6
# 38940                               97                                    6
# 38941                               97                                    6
#
# ...

# %%
df_parc.columns
# Out:
# Index(['Département (Champ géographique)',
#        'Code Direction (Champ géographique)',
#        'Code Commune (Champ géographique)', 'Nom Commune (Champ géographique)',
#        'Préfixe (Références cadastrales)', 'Section (Références cadastrales)',
#        'N° plan (Références cadastrales)', 'N° de voirie (Adresse parcelle)',
#        'Indice de répétition (Adresse parcelle)',
#        'Code voie MAJIC (Adresse parcelle)',
#        'Code voie rivoli (Adresse parcelle)', 'Nature voie (Adresse parcelle)',
#        'Nom voie (Adresse parcelle)', 'Contenance (Caractéristiques parcelle)',
#        'SUF (Evaluation SUF)', 'Nature culture (Evaluation SUF)',
#        'Contenance (Evaluation SUF)', 'Code droit (Propriétaire(s) parcelle)',
#        'N° MAJIC (Propriétaire(s) parcelle)',
#        'N° SIREN (Propriétaire(s) parcelle)',
#        'Groupe personne (Propriétaire(s) parcelle)',
#        'Forme juridique (Propriétaire(s) parcelle)',
# ...

# %%
df_parc.isna().sum()
# Out:
# Département (Champ géographique)                             0
# Code Direction (Champ géographique)                          0
# Code Commune (Champ géographique)                            0
# Nom Commune (Champ géographique)                             0
# Préfixe (Références cadastrales)                             0
# Section (Références cadastrales)                          1032
# N° plan (Références cadastrales)                             0
# N° de voirie (Adresse parcelle)                       16596611
# Indice de répétition (Adresse parcelle)               19706181
# Code voie MAJIC (Adresse parcelle)                         236
# Code voie rivoli (Adresse parcelle)                        236
# Nature voie (Adresse parcelle)                        15330878
# Nom voie (Adresse parcelle)                               1439
# Contenance (Caractéristiques parcelle)                       0
# SUF (Evaluation SUF)                                  16235891
# ...

# %%
df_loc = pd.concat([pd.read_csv(i, sep=';', encoding='latin', low_memory=False) for i in glob.glob(
    "../0_data/locaux/Fichier des locaux/*.txt",
    recursive=True)])

# %%
df_loc.columns
# Out:
# Index(['Département (Champ géographique)',
#        'Code Direction (Champ géographique)',
#        'Code Commune (Champ géographique)', 'Nom Commune (Champ géographique)',
#        'Préfixe (Références cadastrales)', 'Section (Références cadastrales)',
#        'N° plan (Références cadastrales)',
#        'Bâtiment (Identification du local)',
#        'Entrée (Identification du local)', 'Niveau (Identification du local)',
#        'Porte (Identification du local)', 'N° voirie (Adresse du local)',
#        'Indice de répétition (Adresse du local)',
#        'Code voie MAJIC (Adresse du local)',
#        'Code voie rivoli (Adresse du local)', 'Nature voie (Adresse du local)',
#        'Nom voie (Adresse du local)', 'Code droit (Propriétaire(s) du local)',
#        'N° MAJIC (Propriétaire(s) du local)',
#        'N° SIREN (Propriétaire(s) du local)',
#        'Groupe personne (Propriétaire(s) du local)',
#        'Forme juridique (Propriétaire(s) du local)',
# ...

# %%
df_loc.isna().sum()
# Out:
# Département (Champ géographique)                             0
# Code Direction (Champ géographique)                          0
# Code Commune (Champ géographique)                            0
# Nom Commune (Champ géographique)                             0
# Préfixe (Références cadastrales)                             0
# Section (Références cadastrales)                          1097
# N° plan (Références cadastrales)                             0
# Bâtiment (Identification du local)                         524
# Entrée (Identification du local)                            50
# Niveau (Identification du local)                             0
# Porte (Identification du local)                              0
# N° voirie (Adresse du local)                            158340
# Indice de répétition (Adresse du local)               19982118
# Code voie MAJIC (Adresse du local)                           0
# Code voie rivoli (Adresse du local)                          0
# ...

# %%
df_loc
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 0                                    1                                    0  \
# 1                                    1                                    0
# 2                                    1                                    0
# 3                                    1                                    0
# 4                                    1                                    0
# ...                                ...                                  ...
# 23465                               97                                    6
# 23466                               97                                    6
# 23467                               97                                    6
# 23468                               97                                    6
# 23469                               97                                    6
#
# ...

# %% [markdown]
# ### Tests

# %%
test = df_loc.loc[(df_loc['Département (Champ géographique)'] == 75) &
            (df_loc['Code Commune (Champ géographique)']== 102) &
            (df_loc['Section (Références cadastrales)']== 'AC') &
            (df_loc['N° plan (Références cadastrales)']== 93)]
test
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 20370                               75                                    4  \
# 20371                               75                                    4
# 20372                               75                                    4
# 20373                               75                                    4
# 20374                               75                                    4
# ...                                ...                                  ...
# 20433                               75                                    4
# 20434                               75                                    4
# 20435                               75                                    4
# 20436                               75                                    4
# 20437                               75                                    4
#
# ...

# %%
test
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 20370                               75                                    4  \
# 20371                               75                                    4
# 20372                               75                                    4
# 20373                               75                                    4
# 20374                               75                                    4
# ...                                ...                                  ...
# 20433                               75                                    4
# 20434                               75                                    4
# 20435                               75                                    4
# 20436                               75                                    4
# 20437                               75                                    4
#
# ...

# %%
test[test['N° voirie (Adresse du local)'] == 2.0]
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 20392                               75                                    4  \
#
#        Code Commune (Champ géographique) Nom Commune (Champ géographique)
# 20392                                102                         PARIS 02  \
#
#       Préfixe (Références cadastrales) Section (Références cadastrales)
# 20392                                                                AC  \
#
#        N° plan (Références cadastrales) Bâtiment (Identification du local)
# 20392                                93                                  A  \
#
#       Entrée (Identification du local)  Niveau (Identification du local)
# 20392                               02                                 0  \
#
#        Porte (Identification du local)  N° voirie (Adresse du local)
# 20392                             1001                           2.0  \
#
#       Indice de répétition (Adresse du local)
# ...

# %%
t = df_parc[['Département (Champ géographique)',
       'Code Direction (Champ géographique)',
       'Code Commune (Champ géographique)', 'Nom Commune (Champ géographique)',
       'Préfixe (Références cadastrales)', 'Section (Références cadastrales)',
       'N° plan (Références cadastrales)','N° SIREN (Propriétaire(s) parcelle)']].groupby(['Département (Champ géographique)',
       'Code Direction (Champ géographique)',
       'Code Commune (Champ géographique)', 'Nom Commune (Champ géographique)',
       'Préfixe (Références cadastrales)', 'Section (Références cadastrales)',
       'N° plan (Références cadastrales)']).nunique().reset_index()

# %%
test1 = df_parc.loc[(df_parc['N° SIREN (Propriétaire(s) parcelle)'] == '528694953')]
test1
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 90327                               78                                    0  \
# 90328                               78                                    0
# 90413                               78                                    0
# 90414                               78                                    0
# 90417                               78                                    0
# 90418                               78                                    0
# 90431                               78                                    0
# 90432                               78                                    0
# 90433                               78                                    0
# 90434                               78                                    0
#
#        Code Commune (Champ géographique) Nom Commune (Champ géographique)
# ...

# %%
t['N° SIREN (Propriétaire(s) parcelle)'].unique()
# Out:
# array([1, 2, 3, 0, 5, 4, 6], dtype=int64)

# %%
t[t['N° SIREN (Propriétaire(s) parcelle)']!=1]
# Out:
#          Département (Champ géographique)
# 11                                      1  \
# 840                                     1
# 843                                     1
# 853                                     1
# 855                                     1
# ...                                   ...
# 16570441                               2B
# 16570442                               2B
# 16570476                               2B
# 16570482                               2B
# 16570483                               2B
#
#           Code Direction (Champ géographique)
# 11                                          0  \
# 840                                         0
# 843                                         0
# 853                                         0
# 855                                         0
# ...                                       ...
# 16570441                                    0
# 16570442                                    0
# ...

# %%
t['parcelle'] = (t['Département (Champ géographique)'].astype(str)) + t['Section (Références cadastrales)'].astype(str) + (t['N° plan (Références cadastrales)'].astype(str)) + t['Nom Commune (Champ géographique)'].astype(str)

# %%
df_loc['parcelle'] = (df_loc['Département (Champ géographique)'].astype(str)) + df_loc['Section (Références cadastrales)'].astype(str) + (df_loc['N° plan (Références cadastrales)'].astype(str)) + df_loc['Nom Commune (Champ géographique)'].astype(str)

# %%
t2 = df_loc[df_loc['parcelle'].isin(t[t['N° SIREN (Propriétaire(s) parcelle)']!=1]['parcelle'].unique())]

# %%
t2
# Out:
#       Département (Champ géographique)  Code Direction (Champ géographique)
# 59                                   1                                    0  \
# 60                                   1                                    0
# 61                                   1                                    0
# 62                                   1                                    0
# 63                                   1                                    0
# ...                                ...                                  ...
# 21263                               97                                    6
# 21264                               97                                    6
# 21265                               97                                    6
# 21284                               97                                    6
# 21285                               97                                    6
#
# ...
