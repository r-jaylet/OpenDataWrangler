# %%
import sys
sys.path.append('../1_format/')
sys.path.append('../2_analyse/')

# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn
import numpy as np
import glob
import geopandas
from matplotlib.pyplot import figure
seaborn.set()

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Format BODACC

# %%
df_bodacc = pd.read_csv('../0_data/annonces-commerciales.csv', 
                        usecols=['id', 'dateparution', 'numeroannonce', 'jugement', 'numerodepartement', 'region_code',
                                 'tribunal', 'commercant', 'ville', 'registre'],
                        sep=';')

# %%
# get jugement info
df_bodacc = df_bodacc.dropna(subset='jugement')
df_bodacc['jugement_nature'] = df_bodacc['jugement'].apply(lambda x: json.loads(x)['nature'])
df_bodacc['jugement_famille'] = df_bodacc['jugement'].apply(lambda x: json.loads(x)['famille'])
df_bodacc['jugement_date'] = df_bodacc['jugement'].apply(lambda x: json.loads(x)['date'] if 'date' in json.loads(x) else '')
df_bodacc['jugement_complement'] = df_bodacc['jugement'].apply(lambda x: json.loads(x)['complementJugement'] 
                                                               if 'complementJugement' in json.loads(x) else '')
df_bodacc = df_bodacc.drop('jugement', axis=1)

# %%
# fix error import
df_bodacc['jugement_famille'] = df_bodacc['jugement_famille'].replace('Jugement prononÃ§ant', 'Jugement prononçant')
df_bodacc['jugement_famille'] = df_bodacc['jugement_famille'].replace('Avis de dÃ©pÃ´t', 'Avis de dépôt')
df_bodacc['jugement_famille'] = df_bodacc['jugement_famille'].replace('Jugement de clÃ´ture', 'Jugement de clôture')
df_bodacc['jugement_famille'] = df_bodacc['jugement_famille'].replace("ArrÃªt de la Cour d'Appel", "Arrêt de la Cour d'Appel")

# %%
# get rid of null siren with no info
df_bodacc = df_bodacc.dropna(subset='registre')
df_bodacc['registre'] = df_bodacc['registre'].astype(str)
df_bodacc['registre'] = df_bodacc['registre'].apply(lambda x : x.replace('000 000 000,000000000,', ''))
df_bodacc = df_bodacc[df_bodacc['registre'] != '000 000 000,000000000']

# %%
# extract SIREN
df_bodacc['SIREN'] = df_bodacc['registre'].apply(lambda x: x.split(',')[0].replace(' ', ''))
df_bodacc = df_bodacc.drop('registre', axis=1)

# %%
# format dates
df_bodacc['dateparution'] = pd.to_datetime(df_bodacc['dateparution'])
df_bodacc['jugement_date'] = pd.to_datetime(df_bodacc['jugement_date'], format='mixed', dayfirst=True, errors='ignore')

# %%
df_bodacc = df_bodacc.sort_values(by=['dateparution', 'SIREN'])

# %%
len(df_bodacc)
# Out:
# 2451404

# %%
len(df_bodacc.SIREN.unique())
# Out:
# 900242

# %%
# keep only relevant categories
df_bodacc = df_bodacc.loc[(df_bodacc['jugement_famille'] != 'Rétractation sur tierce opposition') & 
                          (df_bodacc['jugement_famille'] != 'Loi de 1967') &
                          (df_bodacc['jugement_famille'] != "Arrêt de la Cour d'Appel")]

# %%
# convert to simple sub categories of judgements
df_bodacc.loc[(df_bodacc['jugement_famille'] == 'Jugement prononçant') & (df_bodacc['jugement_nature'] != 'Jugement de conversion en liquidation judiciaire'), 'jugement_nature'] = 'Autre jugement'
df_bodacc.loc[(df_bodacc['jugement_famille'] == 'Jugement de clôture') & (df_bodacc['jugement_nature'] != "Jugement de clôture pour insuffisance d'actif"), 'jugement_nature'] = 'Autre jugement'
df_bodacc.loc[(df_bodacc['jugement_famille'] == "Jugement d'ouverture") & ((df_bodacc['jugement_nature'] != "Jugement d'ouverture de liquidation judiciaire") & (df_bodacc['jugement_nature'] != "Jugement d'ouverture d'une procédure de redressement judiciaire")), 'jugement_nature'] = 'Autre jugement'
df_bodacc.loc[(df_bodacc['jugement_famille'] == "Avis de dépôt") & (df_bodacc['jugement_nature'] != "Dépôt de l'état des créances"), 'jugement_nature'] = 'Autre jugement'

# %%
# simplify jugemetn nature for ouverture
df_bodacc.loc[df_bodacc['jugement_nature'] == "Jugement d'ouverture de liquidation judiciaire", "jugement_famille"] = "Jugement d'ouverture de liquidation"
df_bodacc.loc[df_bodacc['jugement_nature'] == "Jugement d'ouverture d'une procédure de redressement judiciaire", "jugement_famille"] = "Jugement d'ouverture de redressement"
df_bodacc.loc[df_bodacc['jugement_nature'] == "Autre jugement", "jugement_famille"] = "Jugement d'ouverture autre"

# %%
len(df_bodacc)
# Out:
# 2443796

# %%
df_bodacc = df_bodacc[(df_bodacc.jugement_date > '2020-01-01')]
 # format other type of date TO FIX
df_bodacc['year'] = df_bodacc['jugement_date'].apply(lambda x: str(x)[:4])
df_bodacc = df_bodacc[df_bodacc['year'].isin(['2020', '2021', '2022', '2023'])]

# %%
df_bodacc = df_bodacc[df_bodacc.numerodepartement.isin(['75', '77', '78', '91', '92', '93', '94', '95'])]

# %%
len(df_bodacc)
# Out:
# 84549

# %% [markdown]
# ### Format BODACC liquidation

# %%
df_bodacc_liq = df_bodacc[df_bodacc.jugement_famille == "Jugement d'ouverture de liquidation"].drop_duplicates('SIREN',
                                                                                                               keep='last')

# %%
len(df_bodacc_liq)
# Out:
# 21544

# %%
df_bodacc_liq.head(3)
# Out:
#                     id dateparution  numeroannonce numerodepartement
# 2034846  A201800912458   2018-05-15           2458                92  \
# 2094554  A202000111863   2020-01-16           1863                91
# 177512   A202000111777   2020-01-16           1777                77
#
#          region_code                          tribunal       commercant
# 2034846         11.0  TRIBUNAL DE COMMERCE DE NANTERRE  GRENELLE EVENTS  \
# 2094554         11.0       TRIBUNAL DE COMMERCE D'EVRY  TRIVIUM CONSEIL
# 177512          11.0     TRIBUNAL DE COMMERCE DE MELUN              TSG
#
#                  ville                                 jugement_nature
# 2034846          Paris  Jugement d'ouverture de liquidation judiciaire  \
# 2094554        Mennecy  Jugement d'ouverture de liquidation judiciaire
# 177512   Vaux-le-Pénil  Jugement d'ouverture de liquidation judiciaire
#
#                             jugement_famille jugement_date
# 2034846  Jugement d'ouverture de liquidation    2020-05-03  \
# 2094554  Jugement d'ouverture de liquidation    2020-01-06
# 177512   Jugement d'ouverture de liquidation    2020-01-06
#
#                                        jugement_complement      SIREN  year
# 2034846  Jugement prononçant la liquidation judiciaire,...  820473312  2020
# 2094554  Jugement prononçant la liquidation judiciaire,...  347896128  2020
# 177512   Jugement prononçant la liquidation judiciaire,...  377517057  2020

# %% [markdown]
# ### Import other bases

# %%
# get SIREN of companies that are PM
SIREN = pd.read_csv('../0_data/base_sirene/StockUniteLegale_utf8.csv', 
                    usecols=['siren', 'denominationUniteLegale', 'prenom1UniteLegale'],
                    dtype = {'siren': str})
SIREN = SIREN[SIREN.prenom1UniteLegale.isna()]
# Out:
# C:\Users\RémiJAYLET\AppData\Local\Temp\ipykernel_19240\706957035.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   SIREN = pd.read_csv('../0_data/base_sirene/StockUniteLegale_utf8.csv',

# %%
df_bodacc_liq = df_bodacc_liq[df_bodacc_liq.SIREN.isin(list(SIREN.siren))]

# %%
len(df_bodacc_liq)
# Out:
# 20928

# %%
df_parc1 = pd.concat([pd.read_csv(i,
                                  sep=';',
                                  encoding='latin',
                                  low_memory=False,
                                  dtype={'Département (Champ géographique)' : str,
                                         'Code Direction (Champ géographique)' : str,
                                         'Code Commune (Champ géographique)' : str,
                                         'Préfixe (Références cadastrales)' : str,
                                         'Section (Références cadastrales)' : str,
                                         'N° plan (Références cadastrales)' : str}) for i in glob.glob(
    "../0_data/parcelles/Fichier des parcelles (situation 2022)-dept 01 à 61/Fichier des parcelles (situation 2022)-dpts 01 à 61/*.txt", recursive=True)])

df_parc2 = pd.concat([pd.read_csv(i, sep=';',
                                  encoding='latin',
                                  low_memory=False,
                                  dtype={'Département (Champ géographique)' : str,
                                         'Code Direction (Champ géographique)' : str,
                                         'Code Commune (Champ géographique)' : str,
                                         'Préfixe (Références cadastrales)' : str,
                                         'Section (Références cadastrales)' : str,
                                         'N° plan (Références cadastrales)' : str}) for i in glob.glob(
    "../0_data/parcelles/Fichier des parcelles (situation 2022)-dept 62 à 976/Fichier des parcelles (situation 2022)-dpts 62 à 976/*.txt", recursive=True)])

df_parc = pd.concat([df_parc1, df_parc2], axis=0)

# %%
df_loc = pd.concat([pd.read_csv(i,
                                sep=';',
                                encoding='latin',
                                low_memory=False,
                                dtype={'Département (Champ géographique)' : str,
                                         'Code Direction (Champ géographique)' : str,
                                         'Code Commune (Champ géographique)' : str,
                                         'Préfixe (Références cadastrales)' : str,
                                         'Section (Références cadastrales)' : str,
                                         'N° plan (Références cadastrales)' : str}) for i in glob.glob(
    "../0_data/locaux/Fichier des locaux/*.txt",
    recursive=True)])

# %%
SIRET = pd.read_csv('../0_data/base_sirene/StockEtablissement_utf8.csv',
                    usecols=['siren', 'siret', 'libelleVoieEtablissement', 'libelleCommuneEtablissement'],
                    dtype = {'siren': str, 'siret': str, 'libelleVoieEtablissement': str, 'libelleCommuneEtablissement': str})

# %% [markdown]
# ### Analysis

# %%
df = df_bodacc_liq.copy()

# %% [markdown]
# #### With parcelles

# %%
parc_bodacc = df.merge(df_parc, left_on='SIREN',
                       right_on = 'N° SIREN (Propriétaire(s) parcelle)',
                       how='left')

# %%
parc_bodacc = parc_bodacc[~parc_bodacc['N° SIREN (Propriétaire(s) parcelle)'].isna()]
parc_bodacc = parc_bodacc.drop_duplicates(['SIREN', 'jugement_date', 'Département (Champ géographique)', 
                                           'Code Commune (Champ géographique)', 'Section (Références cadastrales)',
                                           'Préfixe (Références cadastrales)', 'N° plan (Références cadastrales)'])

# %%
parc_bodacc
# Out:
#                   id dateparution  numeroannonce numerodepartement
# 965    A202000372626   2020-02-21           2626                93  \
# 966    A202000372626   2020-02-21           2626                93
# 1420   A202000512680   2020-03-12           2680                75
# 1421   A202000512680   2020-03-12           2680                75
# 1890   A202000641286   2020-03-31           1286                75
# ...              ...          ...            ...               ...
# 21468  A202301002246   2023-05-25           2246                78
# 21469  A202301002246   2023-05-25           2246                78
# 21470  A202301002246   2023-05-25           2246                78
# 21471  A202301002246   2023-05-25           2246                78
# 21472  A202301002246   2023-05-25           2246                78
#
#        region_code                                      tribunal
# 965           11.0               TRIBUNAL DE COMMERCE DE BOBIGNY  \
# 966           11.0               TRIBUNAL DE COMMERCE DE BOBIGNY
# 1420          11.0                 TRIBUNAL DE COMMERCE DE PARIS
# 1421          11.0                 TRIBUNAL DE COMMERCE DE PARIS
# 1890          11.0                 TRIBUNAL DE COMMERCE DE PARIS
# ...            ...                                           ...
# 21468         11.0  Greffe du Tribunal de Commerce de Versailles
# 21469         11.0  Greffe du Tribunal de Commerce de Versailles
# 21470         11.0  Greffe du Tribunal de Commerce de Versailles
# 21471         11.0  Greffe du Tribunal de Commerce de Versailles
# 21472         11.0  Greffe du Tribunal de Commerce de Versailles
#
#                        commercant             ville
# 965                         NISHA  Épinay-sur-Seine  \
# 966                         NISHA  Épinay-sur-Seine
# 1420                 SARL HAMPTON             Paris
# 1421                 SARL HAMPTON             Paris
# 1890   SCI LES JARDINS DE CANDICE             Paris
# ...                           ...               ...
# 21468              SH L'ESPERANCE        Saint-Père
# 21469              SH L'ESPERANCE        Saint-Père
# 21470              SH L'ESPERANCE        Saint-Père
# 21471              SH L'ESPERANCE        Saint-Père
# 21472              SH L'ESPERANCE        Saint-Père
#
#                                       jugement_nature
# 965    Jugement d'ouverture de liquidation judiciaire  \
# 966    Jugement d'ouverture de liquidation judiciaire
# 1420   Jugement d'ouverture de liquidation judiciaire
# 1421   Jugement d'ouverture de liquidation judiciaire
# 1890   Jugement d'ouverture de liquidation judiciaire
# ...                                               ...
# 21468  Jugement d'ouverture de liquidation judiciaire
# 21469  Jugement d'ouverture de liquidation judiciaire
# 21470  Jugement d'ouverture de liquidation judiciaire
# 21471  Jugement d'ouverture de liquidation judiciaire
# 21472  Jugement d'ouverture de liquidation judiciaire
#
#                           jugement_famille jugement_date
# 965    Jugement d'ouverture de liquidation    2020-02-12  \
# 966    Jugement d'ouverture de liquidation    2020-02-12
# 1420   Jugement d'ouverture de liquidation    2020-02-25
# 1421   Jugement d'ouverture de liquidation    2020-02-25
# 1890   Jugement d'ouverture de liquidation    2020-03-13
# ...                                    ...           ...
# 21468  Jugement d'ouverture de liquidation    2023-05-16
# 21469  Jugement d'ouverture de liquidation    2023-05-16
# 21470  Jugement d'ouverture de liquidation    2023-05-16
# 21471  Jugement d'ouverture de liquidation    2023-05-16
# 21472  Jugement d'ouverture de liquidation    2023-05-16
#
#                                      jugement_complement      SIREN  year
# 965    Jugement prononçant la liquidation judiciaire,...  490874112  2020  \
# 966    Jugement prononçant la liquidation judiciaire,...  490874112  2020
# 1420   Jugement prononçant la liquidation judiciaire,...  380746313  2020
# 1421   Jugement prononçant la liquidation judiciaire,...  380746313  2020
# 1890   Jugement prononçant la liquidation judiciaire,...  530781509  2020
# ...                                                  ...        ...   ...
# 21468  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21469  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21470  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21471  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21472  Jugement prononçant la liquidation judiciaire,...  820222214  2023
#
#       Département (Champ géographique) Code Direction (Champ géographique)
# 965                                 13                                   2  \
# 966                                 13                                   2
# 1420                                60                                   0
# 1421                                60                                   0
# 1890                                77                                   0
# ...                                ...                                 ...
# 21468                               89                                   0
# 21469                               89                                   0
# 21470                               89                                   0
# 21471                               89                                   0
# 21472                               89                                   0
#
#       Code Commune (Champ géographique) Nom Commune (Champ géographique)
# 965                                 112                           VELAUX  \
# 966                                 112                           VELAUX
# 1420                                141                        CHANTILLY
# 1421                                141                        CHANTILLY
# 1890                                114                  CHEVRY-COSSIGNY
# ...                                 ...                              ...
# 21468                               364                       SAINT PERE
# 21469                               364                       SAINT PERE
# 21470                               364                       SAINT PERE
# 21471                               364                       SAINT PERE
# 21472                               364                       SAINT PERE
#
#       Préfixe (Références cadastrales) Section (Références cadastrales)
# 965                                                                  CT  \
# 966                                                                  CT
# 1420                                                                 AE
# 1421                                                                 AE
# 1890                                                                 AB
# ...                                ...                              ...
# 21468                                                                AB
# 21469                                                                AB
# 21470                                                                AB
# 21471                                                                AB
# 21472                                                                AB
#
#       N° plan (Références cadastrales)  N° de voirie (Adresse parcelle)
# 965                               0066                              NaN  \
# 966                               0067                              NaN
# 1420                              0492                             26.0
# 1421                              0493                             26.0
# 1890                              0032                              NaN
# ...                                ...                              ...
# 21468                             0721                              NaN
# 21469                             0794                              NaN
# 21470                             0943                              NaN
# 21471                             0951                              NaN
# 21472                             0955                              NaN
#
#       Indice de répétition (Adresse parcelle)
# 965                                       NaN  \
# 966                                       NaN
# 1420                                      NaN
# 1421                                      NaN
# 1890                                      NaN
# ...                                       ...
# 21468                                     NaN
# 21469                                     NaN
# 21470                                     NaN
# 21471                                     NaN
# 21472                                     NaN
#
#        Code voie MAJIC (Adresse parcelle) Code voie rivoli (Adresse parcelle)
# 965                                 405.0                                B186  \
# 966                                 405.0                                B186
# 1420                                 77.0                                0150
# 1421                                 77.0                                0150
# 1890                                100.0                                0120
# ...                                   ...                                 ...
# 21468                               183.0                                B185
# 21469                                69.0                                B070
# 21470                                69.0                                B070
# 21471                                69.0                                B070
# 21472                                69.0                                B070
#
#       Nature voie (Adresse parcelle) Nom voie (Adresse parcelle)
# 965                              NaN                  GRAND PONT  \
# 966                              NaN                  GRAND PONT
# 1420                             RUE                DES CASCADES
# 1421                             RUE                DES CASCADES
# 1890                             RUE               CHARLES PATHE
# ...                              ...                         ...
# 21468                            NaN                  LE VILLAGE
# 21469                            NaN                  L ENFERMIE
# 21470                            NaN                  L ENFERMIE
# 21471                            NaN                  L ENFERMIE
# 21472                            NaN                  L ENFERMIE
#
#        Contenance (Caractéristiques parcelle) SUF (Evaluation SUF)
# 965                                     564.0                  NaN  \
# 966                                    1054.0                  NaN
# 1420                                    582.0                  NaN
# 1421                                    263.0                  NaN
# 1890                                   1089.0                  NaN
# ...                                       ...                  ...
# 21468                                  1812.0                  NaN
# 21469                                    35.0                  NaN
# 21470                                    24.0                  NaN
# 21471                                   599.0                  NaN
# 21472                                    27.0                  NaN
#
#       Nature culture (Evaluation SUF)  Contenance (Evaluation SUF)
# 965                                 S                        564.0  \
# 966                                 S                       1054.0
# 1420                               AB                        582.0
# 1421                                S                        263.0
# 1890                               AB                       1089.0
# ...                               ...                          ...
# 21468                              AG                       1812.0
# 21469                               S                         35.0
# 21470                               J                         24.0
# 21471                               J                        599.0
# 21472                               J                         27.0
#
#       Code droit (Propriétaire(s) parcelle)
# 965                                       P  \
# 966                                       P
# 1420                                      P
# 1421                                      P
# 1890                                      S
# ...                                     ...
# 21468                                     P
# 21469                                     P
# 21470                                     P
# 21471                                     P
# 21472                                     P
#
#       N° MAJIC (Propriétaire(s) parcelle) N° SIREN (Propriétaire(s) parcelle)
# 965                                PBHTZX                           490874112  \
# 966                                PBHTZX                           490874112
# 1420                               PBCL2T                           380746313
# 1421                               PBCL2T                           380746313
# 1890                               PBFP2S                           530781509
# ...                                   ...                                 ...
# 21468                              PBCWT4                           820222214
# 21469                              PBCWT4                           820222214
# 21470                              PBCWT4                           820222214
# 21471                              PBCWT4                           820222214
# 21472                              PBCWT4                           820222214
#
#       Groupe personne (Propriétaire(s) parcelle)
# 965                                            0  \
# 966                                            0
# 1420                                           0
# 1421                                           0
# 1890                                           0
# ...                                          ...
# 21468                                          0
# 21469                                          0
# 21470                                          0
# 21471                                          0
# 21472                                          0
#
#       Forme juridique (Propriétaire(s) parcelle)
# 965                                         5499  \
# 966                                         5499
# 1420                                        5499
# 1421                                        5499
# 1890                                        6540
# ...                                          ...
# 21468                                       5710
# 21469                                       5710
# 21470                                       5710
# 21471                                       5710
# 21472                                       5710
#
#       Forme juridique abrégée (Propriétaire(s) parcelle)
# 965                                                 SARL  \
# 966                                                 SARL
# 1420                                                SARL
# 1421                                                SARL
# 1890                                                 SCI
# ...                                                  ...
# 21468                                                SAS
# 21469                                                SAS
# 21470                                                SAS
# 21471                                                SAS
# 21472                                                SAS
#
#       Dénomination (Propriétaire(s) parcelle)
# 965                                     NISHA
# 966                                     NISHA
# 1420                                  HAMPTON
# 1421                                  HAMPTON
# 1890               SCI LES JARDINS DE CANDICE
# ...                                       ...
# 21468                           SH LESPERANCE
# 21469                           SH LESPERANCE
# 21470                           SH LESPERANCE
# 21471                           SH LESPERANCE
# 21472                           SH LESPERANCE
#
# [675 rows x 38 columns]

# %%
print('Number of parcelles concerned :', len(parc_bodacc))
# Out:
# Number of parcelles concerned : 675

# %%
print('Number of companies concerned :', len(parc_bodacc.SIREN.unique()))
# Out:
# Number of companies concerned : 118

# %%
parc_bodacc['Préfixe (Références cadastrales)'] = parc_bodacc['Section (Références cadastrales)'].apply(lambda x: '000' if len(x) == 2 else '0000')
parc_bodacc['parcelle_id'] = parc_bodacc['Département (Champ géographique)'] + parc_bodacc['Code Commune (Champ géographique)'] + parc_bodacc['Préfixe (Références cadastrales)'] + parc_bodacc['Section (Références cadastrales)']  + parc_bodacc['N° plan (Références cadastrales)']

# %%
list_cities = ['ALFORTVILLE', 'CHAMPIGNY SUR MARNE', 'FONTENAY SOUS BOIS',
               'ST MAUR DES FOSSES', 'ASNIERES-SUR-SEINE', 'CLICHY', 'LIVRY GARGAN']

parc_bodacc[parc_bodacc['Nom Commune (Champ géographique)'].isin(list_cities)]
# Out:
#                   id dateparution  numeroannonce numerodepartement
# 5652   A202100024350   2021-01-05           4350                75  \
# 5653   A202100024350   2021-01-05           4350                75
# 5654   A202100024350   2021-01-05           4350                75
# 5655   A202100024350   2021-01-05           4350                75
# 7800   A202101032527   2021-05-28           2527                75
# 8312   A202101232874   2021-06-25           2874                94
# 8317   A202101232874   2021-06-25           2874                94
# 8318   A202101232874   2021-06-25           2874                94
# 9929   A202102145791   2021-11-02           5791                75
# 12121  A202200502673   2022-03-11           2673                75
# 13414  A202200992368   2022-05-20           2368                92
# 13415  A202200992368   2022-05-20           2368                92
# 13633  A202201083368   2022-06-03           3368                94
# 20416  A202300713982   2023-04-11           3982                77
# 20417  A202300713982   2023-04-11           3982                77
#
#        region_code                                    tribunal
# 5652          11.0               TRIBUNAL DE COMMERCE DE PARIS  \
# 5653          11.0               TRIBUNAL DE COMMERCE DE PARIS
# 5654          11.0               TRIBUNAL DE COMMERCE DE PARIS
# 5655          11.0               TRIBUNAL DE COMMERCE DE PARIS
# 7800          11.0               TRIBUNAL DE COMMERCE DE PARIS
# 8312          11.0             TRIBUNAL DE COMMERCE DE CRÉTEIL
# 8317          11.0             TRIBUNAL DE COMMERCE DE CRÉTEIL
# 8318          11.0             TRIBUNAL DE COMMERCE DE CRÉTEIL
# 9929          11.0               TRIBUNAL DE COMMERCE DE PARIS
# 12121         11.0     Greffe du Tribunal de Commerce de Paris
# 13414         11.0  Greffe du Tribunal de Commerce de Nanterre
# 13415         11.0  Greffe du Tribunal de Commerce de Nanterre
# 13633         11.0   Greffe du Tribunal de Commerce de Créteil
# 20416         11.0     Greffe du Tribunal de Commerce de Meaux
# 20417         11.0     Greffe du Tribunal de Commerce de Meaux
#
#                              commercant                  ville
# 5652             CABINET ROLET-BONTEMPS                  Paris  \
# 5653             CABINET ROLET-BONTEMPS                  Paris
# 5654             CABINET ROLET-BONTEMPS                  Paris
# 5655             CABINET ROLET-BONTEMPS                  Paris
# 7800                           PROGESCO                  Paris
# 8312                     ADB PATRIMOINE  Saint-Maur-des-Fossés
# 8317                     ADB PATRIMOINE  Saint-Maur-des-Fossés
# 8318                     ADB PATRIMOINE  Saint-Maur-des-Fossés
# 9929                  SAMINVEST 153 SAS                  Paris
# 12121                 SAMINVEST 166 SAS                  Paris
# 13414               CABINET DU TINTORET     Asnières-sur-Seine
# 13415               CABINET DU TINTORET     Asnières-sur-Seine
# 13633                       PARYSOL-SDP    Champigny-sur-Marne
# 20416  LA PENSEE VERTE - AVF PROMOTIONS        Bussy St Martin
# 20417  LA PENSEE VERTE - AVF PROMOTIONS        Bussy St Martin
#
#                                       jugement_nature
# 5652   Jugement d'ouverture de liquidation judiciaire  \
# 5653   Jugement d'ouverture de liquidation judiciaire
# 5654   Jugement d'ouverture de liquidation judiciaire
# 5655   Jugement d'ouverture de liquidation judiciaire
# 7800   Jugement d'ouverture de liquidation judiciaire
# 8312   Jugement d'ouverture de liquidation judiciaire
# 8317   Jugement d'ouverture de liquidation judiciaire
# 8318   Jugement d'ouverture de liquidation judiciaire
# 9929   Jugement d'ouverture de liquidation judiciaire
# 12121  Jugement d'ouverture de liquidation judiciaire
# 13414  Jugement d'ouverture de liquidation judiciaire
# 13415  Jugement d'ouverture de liquidation judiciaire
# 13633  Jugement d'ouverture de liquidation judiciaire
# 20416  Jugement d'ouverture de liquidation judiciaire
# 20417  Jugement d'ouverture de liquidation judiciaire
#
#                           jugement_famille jugement_date
# 5652   Jugement d'ouverture de liquidation    2020-12-17  \
# 5653   Jugement d'ouverture de liquidation    2020-12-17
# 5654   Jugement d'ouverture de liquidation    2020-12-17
# 5655   Jugement d'ouverture de liquidation    2020-12-17
# 7800   Jugement d'ouverture de liquidation    2021-05-12
# 8312   Jugement d'ouverture de liquidation    2021-06-16
# 8317   Jugement d'ouverture de liquidation    2021-06-16
# 8318   Jugement d'ouverture de liquidation    2021-06-16
# 9929   Jugement d'ouverture de liquidation    2021-10-15
# 12121  Jugement d'ouverture de liquidation    2022-02-23
# 13414  Jugement d'ouverture de liquidation    2022-05-11
# 13415  Jugement d'ouverture de liquidation    2022-05-11
# 13633  Jugement d'ouverture de liquidation    2022-05-25
# 20416  Jugement d'ouverture de liquidation    2023-03-27
# 20417  Jugement d'ouverture de liquidation    2023-03-27
#
#                                      jugement_complement      SIREN  year
# 5652   Jugement prononçant la liquidation judiciaire,...  331153676  2020  \
# 5653   Jugement prononçant la liquidation judiciaire,...  331153676  2020
# 5654   Jugement prononçant la liquidation judiciaire,...  331153676  2020
# 5655   Jugement prononçant la liquidation judiciaire,...  331153676  2020
# 7800   Jugement prononçant la liquidation judiciaire ...  682024542  2021
# 8312   Jugement prononçant la liquidation judiciaire,...  798531745  2021
# 8317   Jugement prononçant la liquidation judiciaire,...  798531745  2021
# 8318   Jugement prononçant la liquidation judiciaire,...  798531745  2021
# 9929   Jugement prononçant la liquidation judiciaire,...  813869575  2021
# 12121  Jugement prononçant la liquidation judiciaire,...  821688959  2022
# 13414  Jugement prononçant la liquidation judiciaire,...  402008999  2022
# 13415  Jugement prononçant la liquidation judiciaire,...  402008999  2022
# 13633  Jugement prononçant la liquidation judiciaire,...  331803528  2022
# 20416  Jugement prononçant la liquidation judiciaire,...  801915422  2023
# 20417  Jugement prononçant la liquidation judiciaire,...  801915422  2023
#
#       Département (Champ géographique) Code Direction (Champ géographique)
# 5652                                92                                   1  \
# 5653                                92                                   1
# 5654                                92                                   1
# 5655                                92                                   1
# 7800                                92                                   1
# 8312                                94                                   0
# 8317                                94                                   0
# 8318                                94                                   0
# 9929                                94                                   0
# 12121                               94                                   0
# 13414                               92                                   1
# 13415                               92                                   1
# 13633                               94                                   0
# 20416                               92                                   1
# 20417                               92                                   1
#
#       Code Commune (Champ géographique) Nom Commune (Champ géographique)
# 5652                                024                           CLICHY  \
# 5653                                024                           CLICHY
# 5654                                024                           CLICHY
# 5655                                024                           CLICHY
# 7800                                004               ASNIERES-SUR-SEINE
# 8312                                002                      ALFORTVILLE
# 8317                                068               ST MAUR DES FOSSES
# 8318                                068               ST MAUR DES FOSSES
# 9929                                033               FONTENAY SOUS BOIS
# 12121                               033               FONTENAY SOUS BOIS
# 13414                               004               ASNIERES-SUR-SEINE
# 13415                               004               ASNIERES-SUR-SEINE
# 13633                               017              CHAMPIGNY SUR MARNE
# 20416                               004               ASNIERES-SUR-SEINE
# 20417                               004               ASNIERES-SUR-SEINE
#
#       Préfixe (Références cadastrales) Section (Références cadastrales)
# 5652                              0000                                Q  \
# 5653                              0000                                Q
# 5654                              0000                                Q
# 5655                              0000                                Q
# 7800                               000                               AQ
# 8312                              0000                                Q
# 8317                               000                               AQ
# 8318                              0000                                Q
# 9929                              0000                                B
# 12121                             0000                                B
# 13414                              000                               AK
# 13415                             0000                                O
# 13633                              000                               CP
# 20416                             0000                                Y
# 20417                             0000                                Y
#
#       N° plan (Références cadastrales)  N° de voirie (Adresse parcelle)
# 5652                              0068                             56.0  \
# 5653                              0069                             71.0
# 5654                              0148                             75.0
# 5655                              0179                             75.0
# 7800                              0163                             17.0
# 8312                              0178                             40.0
# 8317                              0083                              1.0
# 8318                              0003                             63.0
# 9929                              0095                            107.0
# 12121                             0281                             39.0
# 13414                             0097                             62.0
# 13415                             0175                             58.0
# 13633                             0268                            685.0
# 20416                             0004                            188.0
# 20417                             0005                            186.0
#
#       Indice de répétition (Adresse parcelle)
# 5652                                      NaN  \
# 5653                                      NaN
# 5654                                      NaN
# 5655                                      NaN
# 7800                                      NaN
# 8312                                      NaN
# 8317                                      NaN
# 8318                                      NaN
# 9929                                      NaN
# 12121                                     NaN
# 13414                                     NaN
# 13415                                     NaN
# 13633                                     NaN
# 20416                                     NaN
# 20417                                     NaN
#
#        Code voie MAJIC (Adresse parcelle) Code voie rivoli (Adresse parcelle)
# 5652                                110.0                                7130  \
# 5653                                 70.0                                4420
# 5654                                 70.0                                4420
# 5655                                 70.0                                4420
# 7800                                304.0                                6660
# 8312                                155.0                                9621
# 8317                                 92.0                                0760
# 8318                                355.0                                6190
# 9929                                353.0                                7205
# 12121                               263.0                                5110
# 13414                               190.0                                3515
# 13415                               352.0                                8160
# 13633                               430.0                                6138
# 20416                               109.0                                0735
# 20417                               109.0                                0735
#
#       Nature voie (Adresse parcelle) Nom voie (Adresse parcelle)
# 5652                             RUE                    DE PARIS  \
# 5653                             RUE              HENRI BARBUSSE
# 5654                             RUE              HENRI BARBUSSE
# 5655                             RUE              HENRI BARBUSSE
# 7800                             RUE                DE NORMANDIE
# 8312                             RUE                 VICTOR HUGO
# 8317                              AV                   DE BRAZZA
# 8318                              AV                  MARINVILLE
# 9929                             RUE                PIERRE CURIE
# 12121                            RUE                 LA FONTAINE
# 13414                             AV                   FAIDHERBE
# 13415                            RUE           DU R P CH GILBERT
# 13633                            RUE                 MARCEL PAUL
# 20416                            RUE            DES BOURGUIGNONS
# 20417                            RUE            DES BOURGUIGNONS
#
#        Contenance (Caractéristiques parcelle) SUF (Evaluation SUF)
# 5652                                    288.0                  NaN  \
# 5653                                    354.0                  NaN
# 5654                                    280.0                  NaN
# 5655                                    290.0                  NaN
# 7800                                    210.0                  NaN
# 8312                                    302.0                  NaN
# 8317                                    561.0                  NaN
# 8318                                    716.0                  NaN
# 9929                                    142.0                  NaN
# 12121                                   344.0                  NaN
# 13414                                   251.0                  NaN
# 13415                                   555.0                  NaN
# 13633                                  1737.0                  NaN
# 20416                                   150.0                  NaN
# 20417                                   144.0                  NaN
#
#       Nature culture (Evaluation SUF)  Contenance (Evaluation SUF)
# 5652                                S                        288.0  \
# 5653                                S                        354.0
# 5654                                S                        280.0
# 5655                                S                        290.0
# 7800                                S                        210.0
# 8312                                S                        302.0
# 8317                                S                        561.0
# 8318                                S                        716.0
# 9929                                S                        142.0
# 12121                               S                        344.0
# 13414                               S                        251.0
# 13415                               S                        555.0
# 13633                               S                       1737.0
# 20416                               S                        150.0
# 20417                              AB                        144.0
#
#       Code droit (Propriétaire(s) parcelle)
# 5652                                      G  \
# 5653                                      G
# 5654                                      G
# 5655                                      G
# 7800                                      S
# 8312                                      S
# 8317                                      S
# 8318                                      S
# 9929                                      G
# 12121                                     P
# 13414                                     S
# 13415                                     S
# 13633                                     U
# 20416                                     G
# 20417                                     G
#
#       N° MAJIC (Propriétaire(s) parcelle) N° SIREN (Propriétaire(s) parcelle)
# 5652                               PBFS74                           331153676  \
# 5653                               PBFS74                           331153676
# 5654                               PBFS74                           331153676
# 5655                               PBFS74                           331153676
# 7800                               PBBPVS                           682024542
# 8312                               PBGDMM                           798531745
# 8317                               PBGDMM                           798531745
# 8318                               PBGDMM                           798531745
# 9929                               PBGG8N                           813869575
# 12121                              PBGLW2                           821688959
# 13414                              PBHS44                           402008999
# 13415                              PBHS44                           402008999
# 13633                              PBFTF9                           331803528
# 20416                              PBH3V5                           801915422
# 20417                              PBH3V5                           801915422
#
#       Groupe personne (Propriétaire(s) parcelle)
# 5652                                           0  \
# 5653                                           0
# 5654                                           0
# 5655                                           0
# 7800                                           0
# 8312                                           0
# 8317                                           0
# 8318                                           0
# 9929                                           0
# 12121                                          0
# 13414                                          0
# 13415                                          0
# 13633                                          0
# 20416                                          0
# 20417                                          0
#
#       Forme juridique (Propriétaire(s) parcelle)
# 5652                                        5710  \
# 5653                                        5710
# 5654                                        5710
# 5655                                        5710
# 7800                                        5710
# 8312                                        5499
# 8317                                        5499
# 8318                                        5499
# 9929                                        5710
# 12121                                       5710
# 13414                                       5710
# 13415                                       5710
# 13633                                       5710
# 20416                                       6541
# 20417                                       6541
#
#       Forme juridique abrégée (Propriétaire(s) parcelle)
# 5652                                                 SAS  \
# 5653                                                 SAS
# 5654                                                 SAS
# 5655                                                 SAS
# 7800                                                 SAS
# 8312                                                SARL
# 8317                                                SARL
# 8318                                                SARL
# 9929                                                 SAS
# 12121                                                SAS
# 13414                                                SAS
# 13415                                                SAS
# 13633                                                SAS
# 20416                                                SCI
# 20417                                                SCI
#
#       Dénomination (Propriétaire(s) parcelle)     parcelle_id
# 5652                   CABINET ROLET BONTEMPS  920240000Q0068
# 5653                   CABINET ROLET BONTEMPS  920240000Q0069
# 5654                   CABINET ROLET BONTEMPS  920240000Q0148
# 5655                   CABINET ROLET BONTEMPS  920240000Q0179
# 7800                              PROGESCO SA  92004000AQ0163
# 8312                      SARL ADB PATRIMOINE  940020000Q0178
# 8317                      SARL ADB PATRIMOINE  94068000AQ0083
# 8318                      SARL ADB PATRIMOINE  940680000Q0003
# 9929                        SAMINVEST 153 SAS  940330000B0095
# 12121                       SAMINVEST 166 SAS  940330000B0281
# 13414                     CABINET DU TINTORET  92004000AK0097
# 13415                     CABINET DU TINTORET  920040000O0175
# 13633                             PARYSOL-SDP  94017000CP0268
# 20416        LA PENSEE VERTE - AVF PROMOTIONS  920040000Y0004
# 20417        LA PENSEE VERTE - AVF PROMOTIONS  920040000Y0005

# %% [markdown]
# #### With locaux

# %%
loc_bodacc = df.merge(df_loc,
                      left_on='SIREN',
                      right_on = 'N° SIREN (Propriétaire(s) du local)',
                      how='left')

# %%
loc_bodacc = loc_bodacc[~loc_bodacc['N° SIREN (Propriétaire(s) du local)'].isna()]
loc_bodacc = loc_bodacc.drop_duplicates(['SIREN', 'jugement_date', 'Département (Champ géographique)', 
                                         'Code Commune (Champ géographique)', 'Section (Références cadastrales)',
                                         'Préfixe (Références cadastrales)', 'N° plan (Références cadastrales)'])

# %%
loc_bodacc
# Out:
#                   id dateparution  numeroannonce numerodepartement
# 961    A202000372709   2020-02-21           2709                94  \
# 966    A202000372626   2020-02-21           2626                93
# 1048   A202000381625   2020-02-23           1625                92
# 1049   A202000381625   2020-02-23           1625                92
# 1052   A202000381625   2020-02-23           1625                92
# ...              ...          ...            ...               ...
# 21730  A202301002246   2023-05-25           2246                78
# 21731  A202301002246   2023-05-25           2246                78
# 21732  A202301002246   2023-05-25           2246                78
# 21733  A202301002246   2023-05-25           2246                78
# 21734  A202301002246   2023-05-25           2246                78
#
#        region_code                                      tribunal
# 961           11.0                TRIBUNAL JUDICIAIRE DE CRÉTEIL  \
# 966           11.0               TRIBUNAL DE COMMERCE DE BOBIGNY
# 1048          11.0              TRIBUNAL DE COMMERCE DE NANTERRE
# 1049          11.0              TRIBUNAL DE COMMERCE DE NANTERRE
# 1052          11.0              TRIBUNAL DE COMMERCE DE NANTERRE
# ...            ...                                           ...
# 21730         11.0  Greffe du Tribunal de Commerce de Versailles
# 21731         11.0  Greffe du Tribunal de Commerce de Versailles
# 21732         11.0  Greffe du Tribunal de Commerce de Versailles
# 21733         11.0  Greffe du Tribunal de Commerce de Versailles
# 21734         11.0  Greffe du Tribunal de Commerce de Versailles
#
#             commercant             ville
# 961    LORENA ET ROGER       Alfortville  \
# 966              NISHA  Épinay-sur-Seine
# 1048   OLESTRE GESTION        Courbevoie
# 1049   OLESTRE GESTION        Courbevoie
# 1052   OLESTRE GESTION        Courbevoie
# ...                ...               ...
# 21730   SH L'ESPERANCE        Saint-Père
# 21731   SH L'ESPERANCE        Saint-Père
# 21732   SH L'ESPERANCE        Saint-Père
# 21733   SH L'ESPERANCE        Saint-Père
# 21734   SH L'ESPERANCE        Saint-Père
#
#                                       jugement_nature
# 961    Jugement d'ouverture de liquidation judiciaire  \
# 966    Jugement d'ouverture de liquidation judiciaire
# 1048   Jugement d'ouverture de liquidation judiciaire
# 1049   Jugement d'ouverture de liquidation judiciaire
# 1052   Jugement d'ouverture de liquidation judiciaire
# ...                                               ...
# 21730  Jugement d'ouverture de liquidation judiciaire
# 21731  Jugement d'ouverture de liquidation judiciaire
# 21732  Jugement d'ouverture de liquidation judiciaire
# 21733  Jugement d'ouverture de liquidation judiciaire
# 21734  Jugement d'ouverture de liquidation judiciaire
#
#                           jugement_famille jugement_date
# 961    Jugement d'ouverture de liquidation    2020-02-02  \
# 966    Jugement d'ouverture de liquidation    2020-02-12
# 1048   Jugement d'ouverture de liquidation    2020-02-13
# 1049   Jugement d'ouverture de liquidation    2020-02-13
# 1052   Jugement d'ouverture de liquidation    2020-02-13
# ...                                    ...           ...
# 21730  Jugement d'ouverture de liquidation    2023-05-16
# 21731  Jugement d'ouverture de liquidation    2023-05-16
# 21732  Jugement d'ouverture de liquidation    2023-05-16
# 21733  Jugement d'ouverture de liquidation    2023-05-16
# 21734  Jugement d'ouverture de liquidation    2023-05-16
#
#                                      jugement_complement      SIREN  year
# 961    Jugement d’ouverture d’une procédure de liquid...  450630488  2020  \
# 966    Jugement prononçant la liquidation judiciaire,...  490874112  2020
# 1048   Jugement prononçant la liquidation judiciaire,...  530316231  2020
# 1049   Jugement prononçant la liquidation judiciaire,...  530316231  2020
# 1052   Jugement prononçant la liquidation judiciaire,...  530316231  2020
# ...                                                  ...        ...   ...
# 21730  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21731  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21732  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21733  Jugement prononçant la liquidation judiciaire,...  820222214  2023
# 21734  Jugement prononçant la liquidation judiciaire,...  820222214  2023
#
#       Département (Champ géographique) Code Direction (Champ géographique)
# 961                                 94                                   0  \
# 966                                 13                                   2
# 1048                                75                                   6
# 1049                                92                                   1
# 1052                                92                                   1
# ...                                ...                                 ...
# 21730                               89                                   0
# 21731                               89                                   0
# 21732                               89                                   0
# 21733                               89                                   0
# 21734                               89                                   0
#
#       Code Commune (Champ géographique) Nom Commune (Champ géographique)
# 961                                 046                   MAISONS ALFORT  \
# 966                                 112                           VELAUX
# 1048                                108                         PARIS 08
# 1049                                044                 LEVALLOIS PERRET
# 1052                                044                 LEVALLOIS PERRET
# ...                                 ...                              ...
# 21730                               364                       SAINT PERE
# 21731                               364                       SAINT PERE
# 21732                               364                       SAINT PERE
# 21733                               364                       SAINT PERE
# 21734                               364                       SAINT PERE
#
#       Préfixe (Références cadastrales) Section (Références cadastrales)
# 961                                                                  AI  \
# 966                                                                  CT
# 1048                                                                 BI
# 1049                                                                  R
# 1052                                                                  V
# ...                                ...                              ...
# 21730                                                                AB
# 21731                                                                AB
# 21732                                                                AB
# 21733                                                                AB
# 21734                                                                AB
#
#       N° plan (Références cadastrales) Bâtiment (Identification du local)
# 961                               0114                                  A  \
# 966                               0066                                  E
# 1048                              0087                                  A
# 1049                              0034                                  A
# 1052                              0184                                 01
# ...                                ...                                ...
# 21730                             0010                                  A
# 21731                             0502                                  A
# 21732                             0508                                  A
# 21733                             0677                                  A
# 21734                             0711                                  A
#
#       Entrée (Identification du local)  Niveau (Identification du local)
# 961                                 02                               0.0  \
# 966                                 01                               0.0
# 1048                                01                               1.0
# 1049                                01                               2.0
# 1052                                01                               0.0
# ...                                ...                               ...
# 21730                               01                               0.0
# 21731                               01                               0.0
# 21732                               01                               0.0
# 21733                               01                               0.0
# 21734                               01                               0.0
#
#        Porte (Identification du local)  N° voirie (Adresse du local)
# 961                             2001.0                        9001.0  \
# 966                             1001.0                        2105.0
# 1048                            2001.0                          20.0
# 1049                            2001.0                          55.0
# 1052                            1001.0                          23.0
# ...                                ...                           ...
# 21730                           1001.0                          25.0
# 21731                           1001.0                          22.0
# 21732                           1001.0                          22.0
# 21733                           1001.0                           1.0
# 21734                           1001.0                          20.0
#
#       Indice de répétition (Adresse du local)
# 961                                       NaN  \
# 966                                       NaN
# 1048                                      NaN
# 1049                                      NaN
# 1052                                      NaN
# ...                                       ...
# 21730                                     NaN
# 21731                                     NaN
# 21732                                       A
# 21733                                     NaN
# 21734                                     NaN
#
#        Code voie MAJIC (Adresse du local) Code voie rivoli (Adresse du local)
# 961                                  84.0                                2585  \
# 966                                 423.0                                4204
# 1048                                149.0                                4921
# 1049                                 58.0                                4785
# 1052                                 73.0                                6140
# ...                                   ...                                 ...
# 21730                               200.0                                0160
# 21731                               200.0                                0160
# 21732                               200.0                                0160
# 21733                               225.0                                0105
# 21734                               205.0                                0280
#
#       Nature voie (Adresse du local) Nom voie (Adresse du local)
# 961                              NaN         RES DULAC PLAISANCE  \
# 966                               AV                 JEAN PALLET
# 1048                             RUE                 JEAN MERMOZ
# 1049                             RUE                JULES GUESDE
# 1052                             RUE                MARIUS AUFAN
# ...                              ...                         ...
# 21730                             GR                  GRANDE RUE
# 21731                             GR                  GRANDE RUE
# 21732                             GR                  GRANDE RUE
# 21733                            RLE               DE L ENFERMIE
# 21734                            RUE   DU MOULIN DES MARGUERITES
#
#       Code droit (Propriétaire(s) du local)
# 961                                       P  \
# 966                                       P
# 1048                                      G
# 1049                                      G
# 1052                                      G
# ...                                     ...
# 21730                                     P
# 21731                                     P
# 21732                                     P
# 21733                                     P
# 21734                                     P
#
#       N° MAJIC (Propriétaire(s) du local) N° SIREN (Propriétaire(s) du local)
# 961                                PBBRBQ                           450630488  \
# 966                                PBHTZX                           490874112
# 1048                               PBN3TJ                           530316231
# 1049                               PBHSFM                           530316231
# 1052                               PBHSFM                           530316231
# ...                                   ...                                 ...
# 21730                              PBCWT4                           820222214
# 21731                              PBCWT4                           820222214
# 21732                              PBCWT4                           820222214
# 21733                              PBCWT4                           820222214
# 21734                              PBCWT4                           820222214
#
#       Groupe personne (Propriétaire(s) du local)
# 961                                            0  \
# 966                                            0
# 1048                                           0
# 1049                                           0
# 1052                                           0
# ...                                          ...
# 21730                                          0
# 21731                                          0
# 21732                                          0
# 21733                                          0
# 21734                                          0
#
#       Forme juridique (Propriétaire(s) du local)
# 961                                         6540  \
# 966                                         5499
# 1048                                        5710
# 1049                                        5710
# 1052                                        5710
# ...                                          ...
# 21730                                       5710
# 21731                                       5710
# 21732                                       5710
# 21733                                       5710
# 21734                                       5710
#
#       Forme juridique abrégée (Propriétaire(s) du local)
# 961                                                  SCI  \
# 966                                                 SARL
# 1048                                                 SAS
# 1049                                                 SAS
# 1052                                                 SAS
# ...                                                  ...
# 21730                                                SAS
# 21731                                                SAS
# 21732                                                SAS
# 21733                                                SAS
# 21734                                                SAS
#
#       Dénomination (Propriétaire(s) du local)
# 961                           LORENA ET ROGER
# 966                                     NISHA
# 1048                          OLESTRE GESTION
# 1049                          OLESTRE GESTION
# 1052                          OLESTRE GESTION
# ...                                       ...
# 21730                           SH LESPERANCE
# 21731                           SH LESPERANCE
# 21732                           SH LESPERANCE
# 21733                           SH LESPERANCE
# 21734                           SH LESPERANCE
#
# [340 rows x 38 columns]

# %%
print('Number of locaux concerned :', len(loc_bodacc))
# Out:
# Number of locaux concerned : 340

# %%
loc_bodacc['Préfixe (Références cadastrales)'] = loc_bodacc['Section (Références cadastrales)'].apply(lambda x: '000' if len(x) == 2 else '0000')
df_loc['Préfixe (Références cadastrales)'] = df_loc['Section (Références cadastrales)'].apply(lambda x: '000' if len(str(x)) == 2 else '0000')

loc_bodacc['parcelle_id'] = loc_bodacc['Département (Champ géographique)'] + loc_bodacc['Code Commune (Champ géographique)']+ loc_bodacc['Préfixe (Références cadastrales)'] + loc_bodacc['Section (Références cadastrales)']  + loc_bodacc['N° plan (Références cadastrales)']
df_loc['parcelle_id'] = df_loc['Département (Champ géographique)'] + df_loc['Code Commune (Champ géographique)'] + df_loc['Préfixe (Références cadastrales)']  + df_loc['Section (Références cadastrales)'] + df_loc['N° plan (Références cadastrales)']

# %%
df_loc_perimetre = df_loc[df_loc['parcelle_id'].isin(loc_bodacc['parcelle_id'].unique())]
count_per_loc = df_loc_perimetre[['parcelle_id','N° SIREN (Propriétaire(s) du local)']].groupby('parcelle_id').count()
print('Proportion of locaux  where there is unique SIREN in it: ',
      round(100*len(count_per_loc[count_per_loc['N° SIREN (Propriétaire(s) du local)']!=1])/len(count_per_loc),2), '%' )
# Out:
# Proportion of locaux  where there is unique SIREN in it:  80.95 %

# %% [markdown]
# #### With SIRET

# %%
siret_bodacc = df.merge(SIRET, left_on='SIREN',
                               right_on = 'siren',
                               how='left')

# %%
len(siret_bodacc)
# Out:
# 38262

# %%
siret_bodacc_loc = siret_bodacc.merge(loc_bodacc, how='left',
                                      left_on=['siren', 'libelleVoieEtablissement', 'libelleCommuneEtablissement'],
                                      right_on=['N° SIREN (Propriétaire(s) du local)',
                                                'Nom voie (Adresse du local)', 'Nom Commune (Champ géographique)'])

# %%
siret_bodacc_loc = siret_bodacc_loc[['siren', 'siret', 'libelleVoieEtablissement', 'libelleCommuneEtablissement',
                  'Code Commune (Champ géographique)', 'Nom Commune (Champ géographique)',
                  'Bâtiment (Identification du local)',
                  'Entrée (Identification du local)', 'Niveau (Identification du local)',
                  'Porte (Identification du local)', 'N° voirie (Adresse du local)',
                  'Indice de répétition (Adresse du local)',
                  'Code voie MAJIC (Adresse du local)', 'Code voie rivoli (Adresse du local)', 'Nature voie (Adresse du local)',
                  'Nom voie (Adresse du local)', 'Code droit (Propriétaire(s) du local)',
                  'N° MAJIC (Propriétaire(s) du local)',
                  'N° SIREN (Propriétaire(s) du local)',
                  'Groupe personne (Propriétaire(s) du local)',
                  'Forme juridique (Propriétaire(s) du local)',
                  'Forme juridique abrégée (Propriétaire(s) du local)',
                  'Dénomination (Propriétaire(s) du local)', 'parcelle_id']]
siret_bodacc_loc = siret_bodacc_loc[~siret_bodacc_loc['parcelle_id'].isna()]

# %%
len(siret_bodacc_loc)
# Out:
# 25

# %%
siret_bodacc_loc
# Out:
#            siren           siret libelleVoieEtablissement
# 7723   324895788  32489578800010                   BARBES  \
# 7858   799439377  79943937700018       PIERRE BROSSOLETTE
# 7934   488601113  48860111300019      JEAN DE LA FONTAINE
# 12631  451217681  45121768100019    DES CARRIERS ITALIENS
# 12648  622820447  62282044700036         FONTAINE L EPINE
# 15878  419956719  41995671900019           GEORGES MANDEL
# 17200  389205592  38920559200097            MARYSE BASTIE
# 17204  389205592  38920559200139              JEAN MOULIN
# 17205  389205592  38920559200139              JEAN MOULIN
# 17535  338276090  33827609000010         DE LA REPUBLIQUE
# 17536  338276090  33827609000028         DE LA REPUBLIQUE
# 21977  498385202  49838520200011   DE LA DIVISION LECLERC
# 21978  502403728  50240372800012             DE GUISSERAY
# 21979  502403728  50240372800012             DE GUISSERAY
# 21980  502403728  50240372800012             DE GUISSERAY
# 23509  572060069  57206006900034         EDOUARD VAILLANT
# 23967  493942346  49394234600054             LA FOURNERIE
# 26350  379259625  37925962500034       BERNARD MOUTARDIER
# 26929  794620815  79462081500017                 GRAVIERS
# 28013  907150031  90715003100017        D HERBEAUVILLIERS
# 32298  492353149  49235314900023          PIERRE DE MARCA
# 33058  835191693  83519169300042       DE L ORME A MARTIN
# 35745  898542709  89854270900024         DES DISTILLERIES
# 35746  898542709  89854270900024         DES DISTILLERIES
# 36072  842582645  84258264500011            DE BEAUSEJOUR
#
#       libelleCommuneEtablissement Code Commune (Champ géographique)
# 7723                     PARIS 18                               118  \
# 7858                  GARGENVILLE                               267
# 7934                     PARIS 16                               116
# 12631                      GRIGNY                               286
# 12648                     MORTEAU                               411
# 15878                    PARIS 16                               116
# 17200                        BRON                               029
# 17204                     CHENOVE                               166
# 17205                     CHENOVE                               166
# 17535                   CHATILLON                               020
# 17536                   CHATILLON                               020
# 21977                       LINAS                               339
# 21978                   BREUILLET                               105
# 21979                   BREUILLET                               105
# 21980                   BREUILLET                               105
# 23509                      PANTIN                               055
# 23967                     COGNERS                               085
# 26350             EVIAN-LES-BAINS                               119
# 26929                 ROMAINVILLE                               063
# 28013                  AMPONVILLE                               003
# 32298                         GAN                               230
# 33058          EVRY-COURCOURONNES                               228
# 35745     SAINT-LAURENT-DE-COGNAC                               330
# 35746     SAINT-LAURENT-DE-COGNAC                               330
# 36072                    PARIS 16                               116
#
#       Nom Commune (Champ géographique) Bâtiment (Identification du local)
# 7723                          PARIS 18                                  A  \
# 7858                       GARGENVILLE                                  A
# 7934                          PARIS 16                                  B
# 12631                           GRIGNY                                  A
# 12648                          MORTEAU                                  A
# 15878                         PARIS 16                                  A
# 17200                             BRON                                  A
# 17204                          CHENOVE                                  A
# 17205                          CHENOVE                                  A
# 17535                        CHATILLON                                  A
# 17536                        CHATILLON                                  A
# 21977                            LINAS                                 01
# 21978                        BREUILLET                                  A
# 21979                        BREUILLET                                 AA
# 21980                        BREUILLET                                 BB
# 23509                           PANTIN                                  C
# 23967                          COGNERS                                  A
# 26350                  EVIAN-LES-BAINS                                  A
# 26929                      ROMAINVILLE                                  A
# 28013                       AMPONVILLE                                  A
# 32298                              GAN                                  A
# 33058               EVRY-COURCOURONNES                                  A
# 35745          SAINT-LAURENT-DE-COGNAC                                  A
# 35746          SAINT-LAURENT-DE-COGNAC                                  A
# 36072                         PARIS 16                                 01
#
#       Entrée (Identification du local)  Niveau (Identification du local)
# 7723                                01                              81.0  \
# 7858                                01                               0.0
# 7934                                02                               5.0
# 12631                               01                               0.0
# 12648                               01                               0.0
# 15878                               01                               0.0
# 17200                               01                               0.0
# 17204                               01                               0.0
# 17205                               01                               0.0
# 17535                               01                               0.0
# 17536                               01                               0.0
# 21977                               01                               0.0
# 21978                               01                               0.0
# 21979                               01                               0.0
# 21980                               01                               0.0
# 23509                               01                               0.0
# 23967                               01                               0.0
# 26350                               01                               0.0
# 26929                               01                               0.0
# 28013                               01                               0.0
# 32298                               01                               1.0
# 33058                               01                               0.0
# 35745                               01                               0.0
# 35746                               01                               0.0
# 36072                               01                               0.0
#
#        Porte (Identification du local)  N° voirie (Adresse du local)
# 7723                            2001.0                          42.0  \
# 7858                            1002.0                          27.0
# 7934                            1001.0                          85.0
# 12631                           1001.0                          16.0
# 12648                           1001.0                           4.0
# 15878                           1002.0                          40.0
# 17200                           1001.0                          16.0
# 17204                           1001.0                          18.0
# 17205                           1001.0                          20.0
# 17535                           1001.0                          75.0
# 17536                           1001.0                          75.0
# 21977                             18.0                          40.0
# 21978                           1001.0                          50.0
# 21979                           1001.0                          50.0
# 21980                           1001.0                          50.0
# 23509                           3001.0                          14.0
# 23967                           1001.0                        5147.0
# 26350                           1001.0                           6.0
# 26929                           1001.0                           5.0
# 28013                           1001.0                        5312.0
# 32298                           1039.0                          15.0
# 33058                           1005.0                           5.0
# 35745                           1001.0                          25.0
# 35746                           1001.0                          23.0
# 36072                           1001.0                          17.0
#
#       Indice de répétition (Adresse du local)
# 7723                                      NaN  \
# 7858                                      NaN
# 7934                                      NaN
# 12631                                     NaN
# 12648                                     NaN
# 15878                                     NaN
# 17200                                       B
# 17204                                     NaN
# 17205                                     NaN
# 17535                                     NaN
# 17536                                     NaN
# 21977                                     NaN
# 21978                                     NaN
# 21979                                     NaN
# 21980                                     NaN
# 23509                                     NaN
# 23967                                     NaN
# 26350                                     NaN
# 26929                                     NaN
# 28013                                     NaN
# 32298                                     NaN
# 33058                                     NaN
# 35745                                     NaN
# 35746                                     NaN
# 36072                                     NaN
#
#        Code voie MAJIC (Adresse du local) Code voie rivoli (Adresse du local)
# 7723                                104.0                                0662  \
# 7858                                184.0                                1300
# 7934                                498.0                                5249
# 12631                               242.0                                0147
# 12648                               141.0                                0183
# 15878                               439.0                                4141
# 17200                               166.0                                1192
# 17204                               121.0                                1272
# 17205                               121.0                                1272
# 17535                               169.0                                8135
# 17536                               169.0                                8135
# 21977                                81.0                                0100
# 21978                               180.0                                0250
# 21979                               180.0                                0250
# 21980                               180.0                                0250
# 23509                                69.0                                3120
# 23967                               292.0                                B292
# 26350                                49.0                                0130
# 26929                                97.0                                4170
# 28013                                67.0                                0035
# 32298                               763.0                                1310
# 33058                               675.0                                3235
# 35745                               163.0                                0175
# 35746                               163.0                                0175
# 36072                               252.0                                0794
#
#       Nature voie (Adresse du local) Nom voie (Adresse du local)
# 7723                              BD                      BARBES  \
# 7858                             RUE          PIERRE BROSSOLETTE
# 7934                             RUE         JEAN DE LA FONTAINE
# 12631                            RUE       DES CARRIERS ITALIENS
# 12648                            RUE            FONTAINE L EPINE
# 15878                             AV              GEORGES MANDEL
# 17200                            RUE               MARYSE BASTIE
# 17204                            RUE                 JEAN MOULIN
# 17205                            RUE                 JEAN MOULIN
# 17535                             AV            DE LA REPUBLIQUE
# 17536                             AV            DE LA REPUBLIQUE
# 21977                            RUE      DE LA DIVISION LECLERC
# 21978                            RTE                DE GUISSERAY
# 21979                            RTE                DE GUISSERAY
# 21980                            RTE                DE GUISSERAY
# 23509                             AV            EDOUARD VAILLANT
# 23967                            NaN                LA FOURNERIE
# 26350                            RUE          BERNARD MOUTARDIER
# 26929                            RUE                    GRAVIERS
# 28013                            RTE           D HERBEAUVILLIERS
# 32298                            RUE             PIERRE DE MARCA
# 33058                             AV          DE L ORME A MARTIN
# 35745                            RUE            DES DISTILLERIES
# 35746                            RUE            DES DISTILLERIES
# 36072                             BD               DE BEAUSEJOUR
#
#       Code droit (Propriétaire(s) du local)
# 7723                                      P  \
# 7858                                      P
# 7934                                      P
# 12631                                     P
# 12648                                     P
# 15878                                     P
# 17200                                     P
# 17204                                     P
# 17205                                     P
# 17535                                     P
# 17536                                     P
# 21977                                     P
# 21978                                     P
# 21979                                     P
# 21980                                     P
# 23509                                     P
# 23967                                     P
# 26350                                     P
# 26929                                     P
# 28013                                     P
# 32298                                     P
# 33058                                     P
# 35745                                     P
# 35746                                     P
# 36072                                     P
#
#       N° MAJIC (Propriétaire(s) du local) N° SIREN (Propriétaire(s) du local)
# 7723                               PBG66L                           324895788  \
# 7858                               PBGG4H                           799439377
# 7934                               PBMPS6                           488601113
# 12631                              PBCJJB                           451217681
# 12648                              PBCH34                           622820447
# 15878                              PBJJZ7                           419956719
# 17200                              PBFPPM                           389205592
# 17204                              PBB464                           389205592
# 17205                              PBB464                           389205592
# 17535                              PBJNWN                           338276090
# 17536                              PBJNWN                           338276090
# 21977                              PBCNK6                           498385202
# 21978                              PBC7XH                           502403728
# 21979                              PBC7XH                           502403728
# 21980                              PBC7XH                           502403728
# 23509                              PBC3HW                           572060069
# 23967                              PBCKBD                           493942346
# 26350                              PBB6Z5                           379259625
# 26929                              PBFCR8                           794620815
# 28013                              PBCD7N                           907150031
# 32298                              PBDKRH                           492353149
# 33058                              PBFSSC                           835191693
# 35745                              PBC69X                           898542709
# 35746                              PBC69X                           898542709
# 36072                              PBQJM5                           842582645
#
#       Groupe personne (Propriétaire(s) du local)
# 7723                                           0  \
# 7858                                           0
# 7934                                           0
# 12631                                          0
# 12648                                          0
# 15878                                          0
# 17200                                          0
# 17204                                          0
# 17205                                          0
# 17535                                          0
# 17536                                          0
# 21977                                          0
# 21978                                          0
# 21979                                          0
# 21980                                          0
# 23509                                          0
# 23967                                          0
# 26350                                          0
# 26929                                          0
# 28013                                          0
# 32298                                          0
# 33058                                          0
# 35745                                          0
# 35746                                          0
# 36072                                          0
#
#       Forme juridique (Propriétaire(s) du local)
# 7723                                        5499  \
# 7858                                        6540
# 7934                                        5710
# 12631                                       6540
# 12648                                       5710
# 15878                                       6540
# 17200                                       5499
# 17204                                       5499
# 17205                                       5499
# 17535                                       5499
# 17536                                       5499
# 21977                                       6540
# 21978                                       6540
# 21979                                       6540
# 21980                                       6540
# 23509                                       5710
# 23967                                       5710
# 26350                                       5499
# 26929                                       6540
# 28013                                       5499
# 32298                                       5499
# 33058                                       5710
# 35745                                       6540
# 35746                                       6540
# 36072                                       6540
#
#       Forme juridique abrégée (Propriétaire(s) du local)
# 7723                                                SARL  \
# 7858                                                 SCI
# 7934                                                 SAS
# 12631                                                SCI
# 12648                                                SAS
# 15878                                                SCI
# 17200                                               SARL
# 17204                                               SARL
# 17205                                               SARL
# 17535                                               SARL
# 17536                                               SARL
# 21977                                                SCI
# 21978                                                SCI
# 21979                                                SCI
# 21980                                                SCI
# 23509                                                SAS
# 23967                                                SAS
# 26350                                               SARL
# 26929                                                SCI
# 28013                                               SARL
# 32298                                               SARL
# 33058                                                SAS
# 35745                                                SCI
# 35746                                                SCI
# 36072                                                SCI
#
#                  Dénomination (Propriétaire(s) du local)     parcelle_id
# 7723                                   L ETOILE DE TUNIS  75118000BT0106
# 7858   SOCIETE CIVILE IMMOBILIERE CMM ET PAR ABREVIAT...  78267000AC0002
# 7934                                    BALSA-COMPOSITES  75116000BQ0100
# 12631                                        MOULIN STAR  91286000AP0137
# 12648                        SOCIETE PAGNOT ET COMPAGNIE  25411000AE0304
# 15878                                          LAMARTINE  75116000DV0053
# 17200                                        STARS HOTEL  690290000C1491
# 17204                                        STARS HOTEL  21166000AT0025
# 17205                                        STARS HOTEL  21166000AT0026
# 17535                                     DAS RAVALEMENT  920200000K0128
# 17536                                     DAS RAVALEMENT  920200000K0128
# 21977                                          SCI GISAS  91339000AB0542
# 21978                         SCI LE MOULIN DE GUISSERAY  91105000AW0140
# 21979                         SCI LE MOULIN DE GUISSERAY  91105000AW0141
# 21980                         SCI LE MOULIN DE GUISSERAY  91105000AW0142
# 23509                                     EGRISE MILLION  930550000N0017
# 23967                                             ALCINA  720850000B0283
# 26350                                    J J  IMMOBILIER  74119000AL0226
# 26929                                     SCI  FAMILY  A  93063000AN0171
# 28013                                  PRECISION PROFILS  77003000ZL0067
# 32298                                       LMP COIGNARD  64230000AL0055
# 33058                                          LOCALOURD  91228000AN0183
# 35745                    SCI DU DOMAINE DES DISTILLERIES  16330000AI0422
# 35746                    SCI DU DOMAINE DES DISTILLERIES  16330000AI0423
# 36072                                               NCAB  75116000CN0025
